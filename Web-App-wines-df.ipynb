# %%
import pandas as pd

# %%
df = pd.read_csv('winemag-data_first150k.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
# 5           5   Spain  Deep, dense and pure from the opening bell, th...
# 6           6   Spain  Slightly gritty black-fruit aromas include a s...
# 7           7   Spain  Lush cedary black-fruit aromas are luxe and of...
# 8           8      US  This re-named vineyard was formerly bottled as...
# 9           9      US  The producer sources from two blocks of the vi...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# ...

# %%
us_wines = df[df['country']=='US']

# %%
us_wines
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 8                8      US  This re-named vineyard was formerly bottled as...
# 9                9      US  The producer sources from two blocks of the vi...
# 11              11      US  From 18-year-old vines, this supple well-balan...
# 12              12      US  A standout even in this terrific lineup of 201...
# 14              14      US  With its sophisticated mix of mineral, acid an...
# 15              15      US  First made in 2006, this succulent luscious Ch...
# 16              16      US  This blockbuster, powerhouse of a wine suggest...
# 19              19      US  This fresh and lively medium-bodied wine is be...
# ...

# %%
California = us_wines[us_wines['province']=='California']

# %%
California
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 9                9      US  The producer sources from two blocks of the vi...
# 16              16      US  This blockbuster, powerhouse of a wine suggest...
# 19              19      US  This fresh and lively medium-bodied wine is be...
# 20              20      US  Heitz has made this stellar rosé from the rare...
# 23              23      US  The apogee of this ambitious winery's white wi...
# 24              24      US  San Jose-based producer Adam Comartin heads 1,...
# 28              28      US  Cranberry, baked rhubarb, anise and crushed sl...
# 31              31      US  Steely and perfumed, this wine sees only 20% n...
# 47              47      US  Blended with 9% Malbec, 9% Cabernet Franc and ...
# ...

# %%
NapaValley= California[California['region_1']=='Napa Valley']

# %%
NapaValley
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 20              20      US  Heitz has made this stellar rosé from the rare...
# 67              67      US  From the producer's monumental Atlas Peak vine...
# 77              77      US  Given four months in concrete egg, this is an ...
# 78              78      US  This wine over-delivers in quality for the pri...
# 87              87      US  From a multiplicity of vineyards, this wine wo...
# 89              89      US  A red Meritage driven by 73% Cabernet Sauvigno...
# 101            101      US  Brambly and herbal, this wine shows bright aci...
# 109            109      US  This is from a hillside estate vineyard and is...
# 123            123      US  This wine takes time to unravel and reveal its...
# 134            134      US  While Cabernet Sauvignon dominant, all five re...
# ...

# %%
rose = NapaValley[NapaValley['variety']=='Rosé']

# %%
rose
# Out:
#         Unnamed: 0 country                                        description  \
# 20              20      US  Heitz has made this stellar rosé from the rare...
# 1166          1166      US  This is made from 92% Cabernet Sauvignon and 8...
# 4056          4056      US  Made from Cabernet Sauvignon, Merlot and Petit...
# 12310        12310      US  Cabernet Sauvignon may be the hardest variety ...
# 14527        14527      US  Good acidity and juicy cherry flavors in this ...
# 18329        18329      US  This is a simple, sweet blush wine, with jammy...
# 20092        20092      US  This blend of Cab Sauvignon, Merlot and Cab Fr...
# 31914        31914      US  This darker-salmon-colored rosé combines Sangi...
# 32424        32424      US  Made from Syrah grapes with purpose, not as a ...
# 34340        34340      US  Dark in color for a rosé and full-bodied, this...
# 38483        38483      US  A perfect summer blush wine. Made in the style...
# ...

# %%
rose.shape
# Out:
# (55, 11)

# %%
rose.to_csv('rose.csv')
